# %%
# %matplotlib inline
import os
import re
import nltk
import random
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 12]

# %%
data = []
for sermon in os.listdir('../sermons/preachingtoday'):
    f=open('../sermons/preachingtoday/'+ sermon, 'rb')
    contents =f.read()
    contents = json.loads(contents)
    data.append(contents["text"])

# %%
bible = ["Genesis","Exodus","Leviticus", "Numbers","Deuteronomy", "Joshua", "Judges", "Ruth", "1 Samuel", "2 Samuel",
        "1 Kings", "2 Kings", "1 Chronicles", "2 Chronicles", "Ezra", "Nehemiah", "Esther", "Job", "Psalms",
        "Proverbs", "Ecclesiastes", "Song of Songs", "Isaiah", "Jeremiah", "Lamentations", "Ezekiel", "Daniel",
        "Hosea", "Joel", "Amos", "Obadiah", "Jonah", "Micah", "Nahum", "Habakkuk", "Zephaniah", "Haggai","Zechariah",
        "Malachi", "Matthew", "Mark", "Luke", "John", "Acts", "Romans", "1 Corinthians", "2 Corithians", "Galatians",
        "Ephesians", "Philippians", "Colossians", "1 Thessalonians", "2 Thessalonians", "1 Timothy", "2 Timothy",
        "Titus", "Philemon", "Hebrews", "James", "1 Peter", "2 Peter", "1 John", "2 John", "3 John", "Jude", "Revelation"]

# %%
occurances = []
counts = []
for sermon in data:
    for book in bible:
        for occurance in re.findall(book, sermon):
            occurances.append(book)
for book in bible:
    counts.append(occurances.count(book))

# %%
len(bible)
# Out:
# 66

# %%
y_pos = np.arange(len(bible))
 
plt.bar(y_pos, counts, align='center', alpha=0.5)
plt.xticks(y_pos, bible, rotation='vertical')
plt.ylabel('Usage')
plt.title('References to book in sermon dataset')
 
plt.show()

# %%
fig = plt.figure(1)
ax1  = fig.add_subplot(211)
ax2  = fig.add_subplot(212)

ax1.plot(x,y)
ax1.xaxis.set_ticks(x)

ax2.plot(a, y) #we plot y as a function of a, which parametrizes x
ax2.xaxis.set_ticks(a) #set the ticks to be a
ax2.xaxis.set_ticklabels(x)

# %%
import requests
from requests import get

# %%
page = get('https://api.biblia.com/v1/bible/content/ASV.html?passage=John3&key=fd37d8f28e95d3be8cb4fbc37e15e18e')
html = BeautifulSoup(page, 'html.parser')
html
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ffefc4f7d84a> in <module>()
#       1 page = get('https://api.biblia.com/v1/bible/content/ASV.html?passage=John3&key=fd37d8f28e95d3be8cb4fbc37e15e18e')
# ----> 2 html = BeautifulSoup(page, 'html.parser')
#       3 html
#
# c:\users\zach dunkerton\appdata\local\programs\python\python36\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     243         if hasattr(markup, 'read'):        # It's a file-type object.
#     244             markup = markup.read()
# --> 245         elif len(markup) <= 256 and (
#     246                 (isinstance(markup, bytes) and not b'<' in markup)
#     247                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()
