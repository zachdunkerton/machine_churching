# %%
from get_page import simple_get
from bs4 import BeautifulSoup
import re
import collections
import os
speaker='nee'

# %%
def get_links(html):
    links = []
    for p in html.select('a'):
        if p['href'].find('view=article&aid') > -1 and p.text != 'read more':
            links.append('http://www.sermonindex.net/modules/articles/' + p['href'])
    return links

# %%
def get_sermon_from_link(url):
    page = simple_get(url)
    html = BeautifulSoup(page, 'html.parser')
    tables = html.select('table')
    sermon_text = tables[10].text;
    start_sermon = sermon_text.find('Open as PDF')
    body = sermon_text[start_sermon+11:].strip()
    
    title = sermon_text[:start_sermon].split(':')[2].strip()
    title = title.replace(' ', '_')
    title = title.replace('\"', '')
    title = title.replace('?', '')
    title = title.replace(',', '')
    
    sermon = collections.namedtuple('Sermon', ['title', 'body'])
    sermon.title = title
    
    sermon.body = body
    return sermon

# %%
os.mkdir(speaker)

# %%
def get_sermons(speaker, url):
    for i in range(0,30):
        sermon_index = simple_get(url+str(i))
        html = BeautifulSoup(sermon_index, 'html.parser')
        links = get_links(html)
        os.chdir('./' + speaker) 
        for link in links:
            sermon = get_sermon_from_link(link)
            filename = speaker + '_'  + sermon.title + '.txt'
            with open(filename,'w') as f:
                f.write(sermon.body)
            print('Created ', sermon.title)
        os.chdir('..')
# Out:
# Created  A_flexible_spirit_to_know_God's_will.
# Created  A_FULLY_SOULISH_MAN
# Created  A_SOULISH_CHRISTIAN
# Created  A_World_Under_Water
# Created  AFTER_REGENERATION
# Created  Aids_to_Revelations
# Created  AN_OPEN_LETTER
# Created  Back_to_the_Cross
# Created  CALL_AND_RESPONSE
# Created  Christ_Is_All_Spiritual_Matters_and_Things
# Created  Christian_Sickness
# Created  Christ's_meat_the_will_of_God.
# Created  CO-LABORING_WITH_GOD
# Created  Crucified_Life
# Created  Crucified_Unto_Me
# Created  CRUSHING_SATAN
# Created  Dark_forces_have_been_liberated
# Created  DEFINITIONS
# Created  Deliverance_from_Sin_and_the_Soul_Life
# Created  DELIVERANCE_FROM_THE_FLESH
# Created  Detachment
# Created  Distinctiveness
# Created  DYING_WITH_THE_LORD
# Created  FACT_FAITH_AND_EXPERIENCE
# Created  FOUR_PLANES_OF_THE_SPIRITUAL_LIFE
# Created  GOD'S_WILL
# Created  God's_will_in_suffering.
# Created  Head_Covering
# Created  HIS_OWN_MEDICINE
# Created  HOW_TO_BIND_THE_STRONG_MAN
# Created  HOW_TO_DIFFERENTIATE_BETWEEN
# BEING_SPIRITUAL_AND_BEING_SOULISH
# Created  HOW_TO_OVERCOME_THE_TEMPTER
# Created  HOW_TO_SEEK_AFTER_GOD'S_WILL
# Created  HOW_TO_WALK_BY_THE_SPIRIT
# Created  I_am_doing_a_great_work
# Created  I._THE_ORIGIN_OF_THE_TEMPTER
# Created  IDENTIFYING_THE_ENEMY
# Created  Lights_in_the_World
# Created  LIVING_BY_FAITH
# Created  MAN'S_SPIRIT_SOUL_AND_BODY_AFTER_THE_FALL
# Created  METHODS_OF_WARFARE.
# Created  Ministry_to_the_Lord
# Created  MORE_THAN_CONQUERORS
# Created  Mutual_Refreshing
# Created  My_Laws_in_Their_Hearts
# Created  ONE_BODY_IN_CHRIST
# Created  PRAYER_A_DIVINE_NECESSITY
# Created  PRECIOUS_STONES
# Created  PRINCIPLES_OF_WARFARE.
# Created  REDEMPTION
# Created  REGENERATION
# Created  Robbing_the_Usurper
# Created  Salvation
# Created  SANCTIFICATION
# Created  SATAN_AND_THE_SAINTS
# Created  SATAN_AS_A_ROARING_LION.
# Created  SATAN_AS_AN_ANGEL_OF_LIGHT.
# Created  Shrinking_from_doing_God's_will.
# Created  Sorrow_in_Life
# Created  Spirit_and_Soul
# Created  Spirit_Force_vs._Psychic_Force
# Created  Spirit_Soul_and_Body
# Created  Spiritual_Believers_and_the_Soul
# Created  Spiritual_Energy
# Created  The_Believer's_Ultimate_Attitude_Toward_The_Flesh
# Created  The_Better_Covenant
# Created  THE_BLOOD_OF_CHRIST
# Created  The_Body_of_Christ
# Created  The_Character_of_God's_Workman
# Created  THE_CHARACTERISTIC_OF_A_BELIEVER_HAVING_HIS_SPIRIT_AND_SOUL_MIXED_TOGETHER
# Created  THE_CHIEF_PURPOSE_OF_PRAYER
# Created  The_Christian_and_Psychic_Force
# Created  The_Christian_Life_and_Warfare
# Created  THE_COMBINATION_OF_THE_SOUL_AND_THE_FLESH
# Created  THE_COMMITTED_LIFE
# Created  THE_CONDITION_FOR_GOD'S_PROTECTION
# Created  The_consent_of_the_will.
# Created  THE_COVENANT_OF_GRACE
# Created  THE_CROSS
# Created  The_Cross_and_the_Holy_Spirit
# Created  The_Cross_and_the_New_Covenant!
# Created  The_Cross_and_the_Soul
# Created  THE_CROSS_DESTROYING_THE_SERPENT
# Created  THE_CROSS_OF_CHRIST
# Created  The_Cross_of_Christ_and_Cleansing.
# Created  THE_CRY_FOR_VINDICATION
# Created  The_Dangers_of_Soulish_Life
# Created  THE_DISTINCTION_BETWEEN
# THE_SPIRIT_THE_SOUL_AND_THE_BODY
# Created  THE_DIVIDE_OF_THE_CROSS
# Created  THE_DIVIDING_OF_THE_SPIRIT_FROM_THE_SOUL
# Created  THE_DIVIDING_OF_THE_SPIRIT_FROM_THE_SOUL
# Created  THE_DIVINE_WOUNDING
# Created  The_Duration_of_Such_Prayer
# Created  The_Effect_of_Such_Prayer
# Created  THE_END_TIME
# Created  THE_ETERNAL_PURPOSE
# Created  The_Experience_of_Soulish_Believers
# Created  THE_EXPOSING_OF_THE_ENEMY'S_WILES
# Created  THE_FACE_OF_GOD
# Created  The_Fall_of_Man
# Created  THE_FLESH
# Created  The_Flesh_and_Salvation
# Created  The_Fleshly_or_Carnal_Believer
# Created  THE_FOUNDATION_OF_THE_VICTORIOUS_LIFE
# Created  THE_FREEDOM_OF_THE_CROSS
# Created  THE_FUNCTIONS_OF_THE_SPIRIT
# THE_SOUL_AND_THE_BODY
# Created  THE_GIFTS_OR_THE_GIVER
# Created  THE_GOAL_OF_THE_GOSPEL
# Created  THE_HEIR_AND_THE_PROOF_OF_TIME
# Created  THE_HOLY_SPIRIT
# Created  The_Judge
# Created  The_Latent_Power_of_the_Soul
# Created  THE_LIMITATIONS_OF_THE_TEMPTER
# Created  THE_MAN_IN_THE_LAND
# Created  THE_MEANING_AND_VALUE_OF_ROMANS_SEVEN
# Created  THE_MIGHT_OF_DEATH
# Created  The_Mind_Behind_the_System
# Created  THE_NEW_LIFE_INDWELLING
# Created  The_only_way_into_union_with_Christ.
# Created  The_Opponent
# Created  THE_PARABLE_IN_LUKE_18
# Created  THE_PATH_OF_PROGRESS
# Created  THE_PATH_OF_PROGRESS
# Created  THE_PATH_OF_PROGRESS
# Created  THE_PATH_OF_PROGRESS
# Created  THE_PATH_OF_PROGRESS
# Created  THE_PEACEABLE_FRUIT
# Created  The_Place_of_our_Reconciliation_with_God.
# Created  The_Place_of_Victory_over_Satan.
# Created  The_Powers_of_the_Age_to_Come
# Created  THE_PRACTICAL_STEPS
# Created  THE_PRACTICAL_WAY_OF_VICTORY.
# Created  THE_PRAYER_THAT_OPPOSES_SATAN
# Created  The_Principle_of_Praying_Thrice
# Created  THE_SOUL-LIFE
# Created  THE_STARTING-POINT_OF_RECOVERY
# Created  THE_STATUS_OF_AN_HEIR
# Created  THE_THREE_ASPECTS_OF_PRAYER
# Created  THE_THREE_STAGES_OF_THE_BELIEVERS'_LIFE
# Created  The_Trend_Away_from_God
# Created  THE_UNREGENERATED_MAN_AND_THE_FLESH
# Created  THE_VICTORY_OF_CALVARY.
# Created  THE_WAY_TO_BE_VICTORIOUS_ALL_THE_TIME
# Created  THE_WEALTH_OF_THE_CHILD_OF_GOD
# Created  The_Widow
# Created  THE_WORD_OF_GOD
# Created  THE_WORKS_OF_THE_DEVIL
# Created  THE._CROSS_AND_THE_SOUL_LIFE
# Created  THOSE_WHO_OVERCOME_THE_TEMPTER
# Created  THREE_SIGNIFICANT_MEN
# Created  TRANSLATED_OUT_OF_THE_POWER_OF_DARKNESS
# Created  VICTORY_OVER_THE_WORLD
# Created  WALKING_IN_THE_WILL_OF_GOD
# Created  Watchman_Nee_Quotes
# Created  WHAT_IS_PRAYER
# Created  STRONGER_THAN_HE.
# Created  WHO_HATH_NOT_LIFTED_UP_HIS_SOUL_TO_VANITY.
# Created  YES_TO_GOD_AND_NO_TO_THE_DEVIL.
